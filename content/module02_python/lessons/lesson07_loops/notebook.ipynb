# %% [markdown]
# # Lesson 7: Loops
#
# Learn to repeat operations using for loops, while loops, and loop control statements.

# %% [markdown]
# ## The for Loop

# %%
import math  # noqa: F401

genes = ["BRCA1", "TP53", "EGFR", "MYC"]
for gene in genes:
    print(f"Analyzing {gene}...")
# Out:
# Analyzing BRCA1...
# Analyzing TP53...
# Analyzing EGFR...
# Analyzing MYC...

# %% [markdown]
# ## The range() Function

# %%
print("range(5):", list(range(5)))
print("range(2, 8):", list(range(2, 8)))
print("range(0, 10, 2):", list(range(0, 10, 2)))
print("range(10, 0, -2):", list(range(10, 0, -2)))
# Out:
# range(5): [0, 1, 2, 3, 4]
# range(2, 8): [2, 3, 4, 5, 6, 7]
# range(0, 10, 2): [0, 2, 4, 6, 8]
# range(10, 0, -2): [10, 8, 6, 4, 2]

# %%
# Sum of numbers 1 to 10
total = 0
for i in range(1, 11):
    total += i
print(f"Sum 1 to 10: {total}")
# Out:
# Sum 1 to 10: 55

# %% [markdown]
# ## The while Loop

# %%
count = 0
while count < 5:
    print(f"Count: {count}")
    count += 1
print("Done!")
# Out:
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Done!

# %% [markdown]
# ## Break and Continue

# %%
print("Continue demo (skip 3):")
for i in range(10):
    if i == 3:
        continue
    if i == 7:
        break
    print(i, end=" ")
print("\nBreak at 7")
# Out:
# Continue demo (skip 3):
# 0 1 2 4 5 6
# Break at 7

# %% [markdown]
# ## Nested Loops

# %%
print("Multiplication table (3x3):")
for i in range(1, 4):
    for j in range(1, 4):
        print(f"{i} × {j} = {i * j}", end="\t")
    print()
# Out:
# Multiplication table (3x3):
# 1 × 1 = 1	1 × 2 = 2	1 × 3 = 3
# 2 × 1 = 2	2 × 2 = 4	2 × 3 = 6
# 3 × 1 = 3	3 × 2 = 6	3 × 3 = 9

# %% [markdown]
# ## Enumerate and Zip

# %%
# enumerate() for index and value
genes = ["BRCA1", "TP53", "EGFR"]
for i, gene in enumerate(genes):
    print(f"{i}: {gene}")

print()
# zip() for parallel iteration
expressions = [2.5, 1.8, 3.2]
for gene, expr in zip(genes, expressions):
    print(f"{gene}: {expr}")
# Out:
# 0: BRCA1
# 1: TP53
# 2: EGFR
#
# BRCA1: 2.5
# TP53: 1.8
# EGFR: 3.2

# %% [markdown]
# ## Biotechnology Example

# %%
sequences = [
    "ATCGATCGATCG",
    "GGGGCCCCCAAAA",
    "ATATATATATAT",
    "CGCGCGCGCGCG",
]

for seq in sequences:
    gc = (seq.count("G") + seq.count("C")) / len(seq) * 100
    print(f"{seq}: GC = {gc:.1f}%")
# Out:
# ATCGATCGATCG: GC = 50.0%
# GGGGCCCCCAAAA: GC = 69.2%
# ATATATATATAT: GC = 0.0%
# CGCGCGCGCGCG: GC = 100.0%

# %% [markdown]
# ## SaaS Example

# %%
activity = [
    {"month": "Jan", "users": 1200, "churned": 45},
    {"month": "Feb", "users": 1250, "churned": 38},
    {"month": "Mar", "users": 1300, "churned": 52},
]

total_churned = 0
for m in activity:
    rate = (m["churned"] / m["users"]) * 100
    print(f"{m['month']}: {rate:.1f}% churn")
    total_churned += m["churned"]
print(f"Total churned: {total_churned}")
# Out:
# Jan: 3.8% churn
# Feb: 3.0% churn
# Mar: 4.0% churn
# Total churned: 135

# %% [markdown]
# ## Summary
# - `for` loops iterate over sequences
# - `while` loops repeat on conditions
# - `range()` generates numeric sequences
# - `break` exits, `continue` skips
# - `enumerate()` gives index+value
# - `zip()` iterates multiple sequences in parallel

# %% [markdown]
# ## Exercises
#
# 1. **Basic**: Write a short program that demonstrates the concepts covered in this lesson.
# 2. **Practice**: Modify the examples to work with different inputs.
# 3. **Challenge**: Combine this lesson's concepts with what you learned in previous lessons.
