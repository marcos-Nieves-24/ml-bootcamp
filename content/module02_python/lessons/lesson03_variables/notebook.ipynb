# %% [markdown]
# # Lesson 3: Variables
#
# Learn how to store and manage data using variables in Python.

# %% [markdown]
# ## Basic Variable Assignment

# %%
import math  # noqa: F401

# Assign values to variables
gene = "BRCA1"
expression_level = 2.5
is_mutated = True

print("Gene:", gene)
print("Expression:", expression_level)
print("Mutated:", is_mutated)
# Out:
# Gene: BRCA1
# Expression: 2.5
# Mutated: True

# %% [markdown]
# ## Dynamic Typing

# %%
# Python infers the type from the value
x = 42
print(f"x = {x}, type = {type(x)}")

x = 3.14159
print(f"x = {x}, type = {type(x)}")

x = "Hello"
print(f"x = {x}, type = {type(x)}")

x = [1, 2, 3]
print(f"x = {x}, type = {type(x)}")
# Out:
# x = 42, type = <class 'int'>
# x = 3.14159, type = <class 'float'>
# x = Hello, type = <class 'str'>
# x = [1, 2, 3], type = <class 'list'>

# %% [markdown]
# ## Multiple Assignment

# %%
# Tuple unpacking
a, b, c = 10, 20, 30
print(f"a={a}, b={b}, c={c}")

# Same value to multiple variables
x = y = z = 0
print(f"x={x}, y={y}, z={z}")

# Swapping
a, b = b, a
print(f"After swap: a={a}, b={b}")
# Out:
# a=10, b=20, c=30
# x=0, y=0, z=0
# After swap: a=20, b=10

# %% [markdown]
# ## User Input

# %%
# Simulating user input with hardcoded values
name = "Alice"
age = 30
height = 1.75

print(f"Hello {name}, you are {age} years old and {height}m tall.")
# Out:
# Hello Alice, you are 30 years old and 1.75m tall.

# %% [markdown]
# ## Biotechnology Example: Patient Records

# %%
patient_id = "P-0042"
age = 45
heart_rate = 72
systolic_bp = 120
diastolic_bp = 80
diagnosis = "Hypertension"

print(f"Patient: {patient_id}")
print(f"Age: {age} years")
print(f"Heart Rate: {heart_rate} bpm")
print(f"Blood Pressure: {systolic_bp}/{diastolic_bp} mmHg")
print(f"Diagnosis: {diagnosis}")
# Out:
# Patient: P-0042
# Age: 45 years
# Heart Rate: 72 bpm
# Blood Pressure: 120/80 mmHg
# Diagnosis: Hypertension

# %% [markdown]
# ## SaaS Example: Business Metrics

# %%
company = "DataCloud Inc."
revenue = 125000.50
users = 15420
churn_rate = 0.035
arpu = revenue / users

print(f"Company: {company}")
print(f"Monthly Revenue: ${revenue:,.2f}")
print(f"Active Users: {users:,}")
print(f"Churn Rate: {churn_rate:.1%}")
print(f"ARPU: ${arpu:.2f}")
# Out:
# Company: DataCloud Inc.
# Monthly Revenue: $125,000.50
# Active Users: 15,420
# Churn Rate: 3.5%
# ARPU: $8.11

# %% [markdown]
# ## Summary
#
# - Variables store data in named memory locations
# - Python is dynamically typed — type is inferred from value
# - Use `snake_case` names (PEP 8)
# - `input()` always returns a string
# - Multiple assignment and tuple unpacking are powerful Python features

# %% [markdown]
# ## Exercises
#
# 1. **Basic**: Write a short program that demonstrates the concepts covered in this lesson.
# 2. **Practice**: Modify the examples to work with different inputs.
# 3. **Challenge**: Combine this lesson's concepts with what you learned in previous lessons.
