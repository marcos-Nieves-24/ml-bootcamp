# %% [markdown]
# # Lesson 1: Installing Python
#
# This notebook accompanies the installation lesson. It verifies your Python environment is set up correctly.

# %%
import sys
import platform

print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
print(f"Platform: {platform.platform()}")
# Out:
# Python version: 3.14.4 (main, Apr  8 2026, 04:02:31) [GCC 15.2.0]
# Python executable: /usr/bin/python3
# Platform: Linux-6.6.87.2-microsoft-standard-WSL2-x86_64-with-glibc2.43

# %% [markdown]
# ## Checking pip
#
# Let's verify pip is available and check its version.

# %%
import subprocess
result = subprocess.run([sys.executable, '-m', 'pip', '--version'], capture_output=True, text=True)
print(result.stdout)
# Out:
# pip 25.1.1 from /usr/lib/python3/dist-packages/pip (python 3.14)

# %% [markdown]
# ## Checking Installed Packages
#
# Let's see which packages are already installed.

# %%
result = subprocess.run([sys.executable, '-m', 'pip', 'list'], capture_output=True, text=True)
print(result.stdout[:500])
# Out:
# Package                   Version
# ------------------------- -------------
# asttokens                 3.0.1
# attrs                     25.4.0
# autocommand               2.2.2
# Automat                   25.4.16
# babel                     2.17.0
# bcrypt                    5.0.0
# beautifulsoup4            4.15.0
# bleach                    6.4.0
# blinker                   1.9.0
# certifi                   2026.1.4
# chardet                   5.2.0
# click                     8.1.8
# comm                      0.2.3
# co

# %% [markdown]
# ## Testing Package Imports
#
# Try importing common data science packages. Don't worry if some fail — we'll install them in later lessons.

# %%
packages = ['numpy', 'pandas', 'matplotlib', 'scipy', 'sklearn', 'jupyter']
for pkg in packages:
    try:
        exec(f'import {pkg}')
        print(f'✓ {pkg} is installed')
    except ImportError:
        print(f'✗ {pkg} is NOT installed')
# Out:
# ✓ numpy is installed
# ✓ pandas is installed
# ✓ matplotlib is installed
# ✓ scipy is installed
# ✓ sklearn is installed
# ✓ jupyter is installed

# %% [markdown]
# ## Interactive Python Demo
#
# Python can be used as a calculator.

# %%
print("2 + 2 =", 2 + 2)
print("10 / 3 =", 10 / 3)
print("7 * 8 =", 7 * 8)
print("2 ** 10 =", 2 ** 10)
# Out:
# 2 + 2 = 4
# 10 / 3 = 3.3333333333333335
# 7 * 8 = 56
# 2 ** 10 = 1024

# %% [markdown]
# ## Summary
#
# - Python is installed and working
# - pip is available for package management
# - Your environment is ready for the course

# %% [markdown]
# ## Exercises
#
# 1. **Basic**: Write a short program that demonstrates the concepts covered in this lesson.
# 2. **Practice**: Modify the examples to work with different inputs.
# 3. **Challenge**: Combine this lesson's concepts with what you learned in previous lessons.
