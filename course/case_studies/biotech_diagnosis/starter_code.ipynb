# %% [markdown]
# # Case Study 1: Disease Diagnosis from Gene Expression Data
#
# Diagnose a genetic disease using machine learning on gene expression data.

# %% [markdown]
# ## Setup
#
# Run the cell below to import all required libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, classification_report, roc_curve, roc_auc_score
)

plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette('Set2')
np.random.seed(42)
print("All imports successful.")

# %% [markdown]
# ## Task 1: Data Loading and Exploration
#
# Load the gene expression dataset and inspect its structure.

# %%
# TODO: Load the dataset
# df = pd.read_csv(...)

# TODO: Display first 5 rows

# TODO: Display data types

# TODO: Display basic statistics

# TODO: Check for missing values

# TODO: Print dataset shape

# TODO: Print class distribution

# %% [markdown]
# ### Generate the Dataset
#
# Since this is a case study using synthetic data, run the cell below to generate the dataset. In a real scenario, you would load the data from a CSV file.

# %%
def generate_gene_expression_data(n_samples=100, n_genes=20, random_state=42):
    np.random.seed(random_state)
    n_differential = 8
    baseline = np.random.lognormal(mean=1.0, sigma=0.5, size=n_genes)
    expression = np.zeros((n_samples, n_genes))
    labels = np.zeros(n_samples, dtype=int)
    labels[n_samples // 2:] = 1
    np.random.shuffle(labels)
    gene_names = [
        'BRCA1', 'TP53', 'EGFR', 'MYC', 'KRAS', 'PTEN', 'CDKN2A', 'ERBB2',
        'GAPDH', 'ACTB', 'B2M', 'RPLP0', 'TFRC', 'GUSB', 'PGK1', 'PPIA',
        'HPRT1', 'TBP', 'YWHAZ', 'SDHA'
    ]
    for i in range(n_samples):
        for j in range(n_genes):
            expr = np.random.normal(np.log(baseline[j]), 0.3)
            if labels[i] == 1 and j < n_differential:
                fold_change = np.random.uniform(1.5, 3.0)
                expr += np.log(fold_change) * (1 if j % 2 == 0 else -1)
            expression[i, j] = expr
    cols = gene_names + ['Diagnosis']
    data = np.column_stack([expression, labels])
    patient_ids = [f'P_{i+1:03d}' for i in range(n_samples)]
    df = pd.DataFrame(data, columns=cols)
    df.insert(0, 'Patient_ID', patient_ids)
    return df

df = generate_gene_expression_data()
print(f"Dataset created: {df.shape[0]} samples, {df.shape[1] - 2} genes")

# %%
# TODO: Display first 5 rows
# TODO: Display data types and basic info
# TODO: Check for missing values
# TODO: Print class distribution

# %% [markdown]
# ## Task 2: Exploratory Data Analysis
#
# Visualize the data to understand patterns.

# %%
# TODO: Plot KDE of expression values for each class
# Hint: Use sns.kdeplot with hue='Diagnosis'

# TODO: Boxplot for differential genes
# Hint: Use plt.subplots and sns.boxplot

# TODO: Correlation heatmap
# Hint: Use sns.heatmap with df.corr()

# TODO: Identify top 5 genes by variance
# Hint: Use df.var() and sort_values()

# %% [markdown]
# ## Task 3: Feature Selection
#
# Select the most informative genes and prepare data for modeling.

# %%
# TODO: Select top 10 genes by variance
# Hint: Get gene columns, compute variance, sort, pick top 10

# TODO: Create feature matrix X and target vector y

# TODO: Train-test split (70/30, stratified)

# TODO: Standardize features

# %% [markdown]
# ## Task 4: Model Training
#
# Train Logistic Regression and Random Forest classifiers.

# %%
# TODO: Train Logistic Regression
# lr = LogisticRegression(...)

# TODO: Train Random Forest
# rf = RandomForestClassifier(...)

# TODO: Print training and testing accuracy for both models

# %% [markdown]
# ## Task 5: Model Evaluation
#
# Evaluate both models using multiple metrics.

# %%
# TODO: Confusion matrices for both models

# TODO: Classification reports

# TODO: ROC curves with AUC scores

# TODO: Bar chart comparing metrics

# %% [markdown]
# ## Task 6: Feature Importance Interpretation
#
# Identify which genes are most predictive.

# %%
# TODO: Extract feature importances from Random Forest

# TODO: Plot top 10 important genes

# TODO: Compare with Logistic Regression coefficients

# %% [markdown]
# ## Task 7: Biological Interpretation
#
# Write your interpretation in the cell below.

# %% [markdown]
# ### Biological Interpretation
#
# *Write your analysis here. Discuss which genes are most predictive, how these findings relate to the known biology of the disease, and what limitations exist in this study.*
